# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasat2/Jornada_python/blob/main/Projeto_Analise_voo/Projeto_Pandas_Analise_dados_voo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('flights.csv')

# %%
df.head(10)
# Out:
#   Origin Destination    Origin City Destination City  Passengers  Seats  \
# 0    MHK         AMW  Manhattan, KS         Ames, IA          21     30
# 1    EUG         RDM     Eugene, OR         Bend, OR          41    396
# 2    EUG         RDM     Eugene, OR         Bend, OR          88    342
# 3    EUG         RDM     Eugene, OR         Bend, OR          11     72
# 4    MFR         RDM    Medford, OR         Bend, OR           0     18
# 5    MFR         RDM    Medford, OR         Bend, OR          11     18
# 6    MFR         RDM    Medford, OR         Bend, OR           2     72
# 7    MFR         RDM    Medford, OR         Bend, OR           7     18
# 8    MFR         RDM    Medford, OR         Bend, OR           7     36
# 9    SEA         RDM    Seattle, WA         Bend, OR           8     18
#
#    Flights  Distance  Fly Date  Origin Population  Destination Population
# 0        1     254.0    200810             122049                   86219
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3606803 entries, 0 to 3606802
# Data columns (total 11 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   Origin                  object
#  1   Destination             object
#  2   Origin City             object
#  3   Destination City        object
#  4   Passengers              int64
#  5   Seats                   int64
#  6   Flights                 int64
#  7   Distance                float64
#  8   Fly Date                int64
#  9   Origin Population       int64
#  10  Destination Population  int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 302.7+ MB

# %%
df.isnull().sum()
# Out:
# Origin                    0
# Destination               0
# Origin City               0
# Destination City          0
# Passengers                0
# Seats                     0
# Flights                   0
# Distance                  0
# Fly Date                  0
# Origin Population         0
# Destination Population    0
# dtype: int64

# %%
df.describe().round(2)
# Out:
#        Passengers       Seats     Flights    Distance    Fly Date  \
# count  3606803.00  3606803.00  3606803.00  3606803.00  3606803.00
# mean      2688.91     4048.30       37.23      697.32   200063.39
# std       4347.62     6200.87       49.62      604.42      574.67
# min          0.00        0.00        0.00        0.00   199001.00
# 25%        109.00      156.00        2.00      273.00   199603.00
# 50%       1118.00     1998.00       25.00      519.00   200111.00
# 75%       3503.00     5370.00       55.00      927.00   200601.00
# max      89597.00   147062.00     1128.00     5095.00   200912.00
#
#        Origin Population  Destination Population
# count          3606803.0              3606803.00
# mean           5871502.5              5897982.44
# std            7858061.6              7906127.41
# min              13005.0                12887.00
# 25%            1030597.0              1025470.00
# 50%            2400193.0              2400193.00
# ...

# %%
# pegando dados categoricos

df['Origin'].value_counts().head(10)
# Out:
# Origin
# ORD    158496
# ATL    131046
# DFW    106698
# DTW     99624
# MSP     98922
# LAX     87299
# CLT     85615
# PHL     83244
# IAH     81249
# EWR     79810
# Name: count, dtype: int64

# %%
# dados categoricos unicos
# Todos os aeroportos de origem

df['Origin'].unique()
# Out:
# array(['MHK', 'EUG', 'MFR', 'SEA', 'PDX', 'LMT', 'SFO', 'LAX', 'EAT',
#        'YKM', 'EKO', 'SLE', 'GEG', 'RDD', 'LWS', 'AST', 'CLM', 'PDT',
#        'SJC', 'ACV', 'PUW', 'SMF', 'FLL', 'PHX', 'BFI', 'GGG', 'GTF',
#        'FAT', 'TUS', 'MWH', 'BIL', 'DFW', 'RBG', 'SLC', 'CPR', 'RDM',
#        'RNO', 'FBK', 'ANC', 'BIF', 'CIC', 'SAF', 'ABQ', 'FSM', 'LAS',
#        'DQF', 'ICT', 'AZA', 'DLH', 'CEC', 'OKC', 'SAN', 'STS', 'DRO',
#        'OAK', 'IAH', 'ELP', 'DBQ', 'HLN', 'TUL', 'OMA', 'ACT', 'BTM',
#        'AUS', 'PIA', 'CWA', 'PUB', 'FOE', 'COS', 'GJT', 'LBF', 'SPS',
#        'CYS', 'ABR', 'BRD', 'AMA', 'ROW', 'BIS', 'MSO', 'GCC', 'LBB',
#        'LBL', 'MAF', 'MSN', 'LNK', 'ALO', 'RFD', 'GRB', 'LSE', 'FCA',
#        'MKE', 'BLI', 'FOD', 'DSM', 'EAU', 'MCW', 'RAP', 'LIT', 'SHV',
#        'MCI', 'GFK', 'BFL', 'SAT', 'MSP', 'SGF', 'BFF', 'FSD', 'GRI',
#        'CID', 'FYV', 'SUX', 'GCK', 'BTR', 'IDA', 'SPI', 'SBA', 'CRP',
# ...

# %%
# Contando quantos aeroportos
df['Origin'].nunique()
# Out:
# 683

# %%
# Filtrando os dados para coisas menores

#Cenario 1 : Extrair registros de voos apenas no ano 2000

df['Year'] =df['Fly Date'].astype(str).str.slice(0,4) #extraindo os 4 primeiros digitos do ano e transformando em string.
voos2000 = df[df['Year'] == '2000']

# %%
voos2000
# Out:
#         Origin Destination    Origin City       Destination City  Passengers  \
# 636        SEA         RDM    Seattle, WA               Bend, OR        2023
# 637        SEA         RDM    Seattle, WA               Bend, OR        2995
# 638        SEA         RDM    Seattle, WA               Bend, OR        3134
# 639        SEA         RDM    Seattle, WA               Bend, OR        3420
# 640        SEA         RDM    Seattle, WA               Bend, OR        3108
# ...        ...         ...            ...                    ...         ...
# 3606696    STL         TBN  St. Louis, MO  Fort Leonard Wood, MO         663
# 3606697    STL         TBN  St. Louis, MO  Fort Leonard Wood, MO         166
# 3606698    STL         TBN  St. Louis, MO  Fort Leonard Wood, MO         548
# 3606699    STL         TBN  St. Louis, MO  Fort Leonard Wood, MO         456
# 3606700    STL         TBN  St. Louis, MO  Fort Leonard Wood, MO         589
#
# ...

# %%
#Cenario 2 : Encontre voos que nao incluam LAX como origem

voos_sem_lax = df[df['Origin'] != 'LAX']

# %%
voos_sem_lax
# Out:
#         Origin Destination         Origin City            Destination City  \
# 0          MHK         AMW       Manhattan, KS                    Ames, IA
# 1          EUG         RDM          Eugene, OR                    Bend, OR
# 2          EUG         RDM          Eugene, OR                    Bend, OR
# 3          EUG         RDM          Eugene, OR                    Bend, OR
# 4          MFR         RDM         Medford, OR                    Bend, OR
# ...        ...         ...                 ...                         ...
# 3606798    STL         TBN       St. Louis, MO       Fort Leonard Wood, MO
# 3606799    STL         TBN       St. Louis, MO       Fort Leonard Wood, MO
# 3606800    STL         TBN       St. Louis, MO       Fort Leonard Wood, MO
# 3606801    CGI         TBN  Cape Girardeau, MO       Fort Leonard Wood, MO
# 3606802    FWA         OH1      Fort Wayne, IN  Washington Court House, OH
#
# ...

# %%
# Cenario 3 : Voos que incluam LAX


voos_lax = df[df['Origin'] =='LAX']

voos_lax
# Out:
#         Origin Destination      Origin City      Destination City  Passengers  \
# 73         LAX         RDM  Los Angeles, CA              Bend, OR        1599
# 74         LAX         RDM  Los Angeles, CA              Bend, OR         643
# 75         LAX         RDM  Los Angeles, CA              Bend, OR        1280
# 76         LAX         RDM  Los Angeles, CA              Bend, OR          66
# 1112       LAX         RDM  Los Angeles, CA              Bend, OR         154
# ...        ...         ...              ...                   ...         ...
# 3606280    LAX         HII  Los Angeles, CA  Lake Havasu City, AZ         186
# 3606281    LAX         HII  Los Angeles, CA  Lake Havasu City, AZ         991
# 3606282    LAX         HII  Los Angeles, CA  Lake Havasu City, AZ         822
# 3606283    LAX         HII  Los Angeles, CA  Lake Havasu City, AZ         745
# 3606284    LAX         HII  Los Angeles, CA  Lake Havasu City, AZ         851
#
# ...

# %% [markdown]
# # Filtro com multiplas condições

# %%
# Cenario 1 : Voos com mais de 100 passageiros e distancia < 1000 milhas

passageiros_distancia = df[(df['Passengers']>100) & df['Distance']< 1000]

# %%
passageiros_distancia
# Out:
#         Origin Destination         Origin City            Destination City  \
# 0          MHK         AMW       Manhattan, KS                    Ames, IA
# 1          EUG         RDM          Eugene, OR                    Bend, OR
# 2          EUG         RDM          Eugene, OR                    Bend, OR
# 3          EUG         RDM          Eugene, OR                    Bend, OR
# 4          MFR         RDM         Medford, OR                    Bend, OR
# ...        ...         ...                 ...                         ...
# 3606798    STL         TBN       St. Louis, MO       Fort Leonard Wood, MO
# 3606799    STL         TBN       St. Louis, MO       Fort Leonard Wood, MO
# 3606800    STL         TBN       St. Louis, MO       Fort Leonard Wood, MO
# 3606801    CGI         TBN  Cape Girardeau, MO       Fort Leonard Wood, MO
# 3606802    FWA         OH1      Fort Wayne, IN  Washington Court House, OH
#
# ...

# %%
# Cenario 2 : Todos os voos de/para nova york ou los angeles 

cidades = df[df['Origin City'].str.contains('New York|Los Angeles') | df['Destination City'].str.contains('New York|Los Angeles')]

# %%
cidades
# Out:
#         Origin Destination      Origin City      Destination City  Passengers  \
# 73         LAX         RDM  Los Angeles, CA              Bend, OR        1599
# 74         LAX         RDM  Los Angeles, CA              Bend, OR         643
# 75         LAX         RDM  Los Angeles, CA              Bend, OR        1280
# 76         LAX         RDM  Los Angeles, CA              Bend, OR          66
# 1112       LAX         RDM  Los Angeles, CA              Bend, OR         154
# ...        ...         ...              ...                   ...         ...
# 3606280    LAX         HII  Los Angeles, CA  Lake Havasu City, AZ         186
# 3606281    LAX         HII  Los Angeles, CA  Lake Havasu City, AZ         991
# 3606282    LAX         HII  Los Angeles, CA  Lake Havasu City, AZ         822
# 3606283    LAX         HII  Los Angeles, CA  Lake Havasu City, AZ         745
# 3606284    LAX         HII  Los Angeles, CA  Lake Havasu City, AZ         851
#
# ...

# %%
# Cenario 3 : Populacao de origem superior a 1 milhao de pessoas 

populacao = df[df['Origin Population']>1000000]

populacao
# Out:
#         Origin Destination    Origin City       Destination City  Passengers  \
# 9          SEA         RDM    Seattle, WA               Bend, OR           8
# 10         SEA         RDM    Seattle, WA               Bend, OR         453
# 11         SEA         RDM    Seattle, WA               Bend, OR         784
# 12         SEA         RDM    Seattle, WA               Bend, OR         749
# 13         SEA         RDM    Seattle, WA               Bend, OR          11
# ...        ...         ...            ...                    ...         ...
# 3606796    STL         TBN  St. Louis, MO  Fort Leonard Wood, MO         331
# 3606797    STL         TBN  St. Louis, MO  Fort Leonard Wood, MO         292
# 3606798    STL         TBN  St. Louis, MO  Fort Leonard Wood, MO         281
# 3606799    STL         TBN  St. Louis, MO  Fort Leonard Wood, MO         245
# 3606800    STL         TBN  St. Louis, MO  Fort Leonard Wood, MO         363
#
# ...

# %%
# CENARIO - Voos que possuem assentos vazios 

voos = df.query('Seats > Passengers')
voos['Destination City']  # locais onde ninguem quer ir muito
# Out:
# 0                       Ames, IA
# 1                       Bend, OR
# 2                       Bend, OR
# 3                       Bend, OR
# 4                       Bend, OR
#                    ...
# 3606797    Fort Leonard Wood, MO
# 3606798    Fort Leonard Wood, MO
# 3606799    Fort Leonard Wood, MO
# 3606800    Fort Leonard Wood, MO
# 3606801    Fort Leonard Wood, MO
# Name: Destination City, Length: 3242926, dtype: object

# %%
# Cenario  - Encontrar voos com menos de 300 milhas e com mais de 10 voos por mes

voos_populares = df.query('Distance < 300 & Flights > 10' )
voos_populares
# Out:
#         Origin Destination    Origin City       Destination City  Passengers  \
# 1          EUG         RDM     Eugene, OR               Bend, OR          41
# 2          EUG         RDM     Eugene, OR               Bend, OR          88
# 10         SEA         RDM    Seattle, WA               Bend, OR         453
# 11         SEA         RDM    Seattle, WA               Bend, OR         784
# 12         SEA         RDM    Seattle, WA               Bend, OR         749
# ...        ...         ...            ...                    ...         ...
# 3606796    STL         TBN  St. Louis, MO  Fort Leonard Wood, MO         331
# 3606797    STL         TBN  St. Louis, MO  Fort Leonard Wood, MO         292
# 3606798    STL         TBN  St. Louis, MO  Fort Leonard Wood, MO         281
# 3606799    STL         TBN  St. Louis, MO  Fort Leonard Wood, MO         245
# 3606800    STL         TBN  St. Louis, MO  Fort Leonard Wood, MO         363
#
# ...

# %%
# Salvar o ultimo cenario em um novo arquivo csv

voos_populares.to_csv('vooslucrativos.csv')

# %% [markdown]
# # Agrupamento

# %%
# Cenario 1 : Agrupando por origem e destino 

grouped = df.groupby(['Origin', 'Destination'])

# Aplicar e agregar uma funcao ao grupo 

aggregated = grouped.agg({'Passengers':'sum'})

#Selecione os valores dessa tabela

sorted_values = aggregated.sort_values(by='Passengers',ascending=False) # maior pro menor

sorted_values.head()
# Out:
#                     Passengers
# Origin Destination
# OGG    HNL            32364612
# HNL    OGG            29744742
# LAX    HNL            28964154
# HNL    LAX            28632161
# LAS    LAX            26333721

# %%
# Cenario 1 : Agrupando por origem e destino 

grouped = df.groupby(['Origin', 'Destination'])

# Aplicar e agregar uma funcao ao grupo 

aggregated = grouped.agg({'Passengers':'sum','Flights':'sum'})

#Selecione os valores dessa tabela

sorted_values = aggregated.sort_values(by=['Passengers','Flights'],ascending=[False,False]) # maior pro menor

sorted_values.head()
# Out:
#                     Passengers  Flights
# Origin Destination
# OGG    HNL            32364612   394909
# HNL    OGG            29744742   389964
# LAX    HNL            28964154   140973
# HNL    LAX            28632161   135848
# LAS    LAX            26333721   291759

# %%
# Cenario 2 : Agrupamento por data de voo

#Convertendo Fly date em datetime e criando mes para agrupamento 

df['Month'] = pd.to_datetime(df['Fly Date'],format = '%Y%m').dt.to_period('M')

#Agrupar por mes e agregar a soma da coluna voos 

grouped = df.groupby('Month')
aggregated = grouped.agg({'Flights':'sum'})

# Classificando por mes 

sorted_values = aggregated.sort_values(by='Month')
sorted_values
# Out:
#          Flights
# Month
# 1990-01   422366
# 1990-02   379961
# 1990-03   429472
# 1990-04   420019
# 1990-05   435517
# ...          ...
# 2009-08   632620
# 2009-09   581047
# 2009-10   602156
# 2009-11   576901
# 2009-12   587123
#
# [240 rows x 1 columns]

# %% [markdown]
# # CUT

# %%
# Criar grupos de intervalos para a distancia 

distance_bins = pd.cut(df['Distance'],bins= [0,500,1000,2000,3000,4000,df['Distance'].max()]) # bins significa que é um trecho.

# %%
# Agrupe por intervalos de distancia e encontre o total de voos e passageiros para cada categoria.

grouped_data = df.groupby(distance_bins).agg({'Flights':'sum','Passengers':'sum'})

#Ordenando do maior pro menor 

sorted = grouped_data.sort_values(by='Distance',ascending = False)
sorted
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_10668\3156414913.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = df.groupby(distance_bins).agg({'Flights':'sum','Passengers':'sum'})
#                    Flights  Passengers
# Distance
# (4000.0, 5095.0]     79750    16272506
# (3000.0, 4000.0]    243395    21409447
# (2000.0, 3000.0]   4890525   653367069
# (1000.0, 2000.0]  19094295  2056781986
# (500.0, 1000.0]   37086403  2982802042
# (0.0, 500.0]      72824152  3967230552

# %%
# Criando graficos 

# Agrupar por origem e agregando a soma dos voos. 
aeroportos = df.groupby('Origin').agg({'Flights':'sum'})

# Encontre os 10 aeroportos de origem mais movimentados
aeroportos_populares = aeroportos.nlargest(10,'Flights')

#Plote os dados 

aeroportos_populares.plot(kind = 'bar')
plt.title('Aeroportos mais populares')
plt.ylabel('Numero de voos')
plt.xticks(rotation = 45)
plt.tight_layout()
plt.show()

# %%
# Cenario 2  # Identificando rotas + populares pela quantidade de passageios

trafego = df.groupby(['Origin','Destination']).agg({'Passengers':'sum'})
rotas_populares = trafego.nlargest(10,'Passengers')

rotas_populares.plot(kind='bar',color = 'purple')
plt.title('Rotas populares')
plt.ylabel('Numero de Passageiros')
plt.xticks(rotation = 45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Grafico de linha

# %%
# Numero de voos a cada ano 

df['Year'] = df['Fly Date'].astype(str).str[:4]
agrupa_ano = df.groupby('Year').agg({'Flights':'sum'})

agrupa_ano.plot(kind='line', color ='red')
plt.title('Número de voos ao longo dos anos')
plt.ylabel('Numero de voos')
plt.xlabel('Ano')
plt.show()

# %%
#  Agregando o número de passageiros e voos por ano 

passageiros = df.groupby('Year').agg({'Flights':'sum','Passengers':'sum'})
passageiros.plot(kind='line')
plt.title('Numero de voos e passageiros por ano')
plt.xlabel('Ano')
plt.ylabel('Numero de voos e passageiros')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# * Os dados acima são muito diferentes, por isso houve uma discrepancia no gráfico, o objetivo da aula foi mostrar isso.

# %% [markdown]
# # Gráfico de Pizza

# %% [markdown]
# * Distribuição dos voos por intervalo de distância

# %%
distance_bins = pd.cut(df['Distance'],bins= [0,500,1000,2000,3000,4000,df['Distance'].max()])
distance_groups = df.groupby(distance_bins).agg({'Flights':'sum'})
distance_groups.plot(kind ='pie', y='Flights',title='Numero de voos por distância')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_10668\1521295463.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   distance_groups = df.groupby(distance_bins).agg({'Flights':'sum'})

# %%
# Qual o total de  passageiros tem de uma cidade para um outra
route_groups = df.groupby(['Origin City', 'Destination City']).agg({'Passengers':'sum'})
top_10_routes = route_groups.nlargest(10,'Passengers')
top_10_routes.plot(kind='pie',y='Passengers',title ='Distribuição de passageiros por rota')
plt.tight_layout()
plt.show()

# %%
df
# Out:
#         Origin Destination         Origin City            Destination City  \
# 0          MHK         AMW       Manhattan, KS                    Ames, IA
# 1          EUG         RDM          Eugene, OR                    Bend, OR
# 2          EUG         RDM          Eugene, OR                    Bend, OR
# 3          EUG         RDM          Eugene, OR                    Bend, OR
# 4          MFR         RDM         Medford, OR                    Bend, OR
# ...        ...         ...                 ...                         ...
# 3606798    STL         TBN       St. Louis, MO       Fort Leonard Wood, MO
# 3606799    STL         TBN       St. Louis, MO       Fort Leonard Wood, MO
# 3606800    STL         TBN       St. Louis, MO       Fort Leonard Wood, MO
# 3606801    CGI         TBN  Cape Girardeau, MO       Fort Leonard Wood, MO
# 3606802    FWA         OH1      Fort Wayne, IN  Washington Court House, OH
#
# ...

# %% [markdown]
# # Gráfico de dispersao -  uteis para visualizar relacoes entre 2 variaveis numericas

# %% [markdown]
# Crie um gráfico de dispersão das rotas agrupadas (Origem/Destino), relacionando a média da distância no eixo X e a soma de passageiros no eixo Y.

# %%
route_groups = df.groupby(['Origin City', 'Destination City']).agg({'Distance':'mean','Passengers':'sum'})
route_groups.plot(kind='scatter', x='Distance',y='Passengers')
plt.title('Numero de passageiros por distância')
plt.xlabel('Distância')
plt.ylabel('Numero de Passageiros')
plt.tight_layout()
plt.show()
