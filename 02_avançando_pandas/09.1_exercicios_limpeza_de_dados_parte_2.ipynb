# %% [markdown]
# Crie um DataFrame df_faturamento com as colunas:
#
# id_venda (1, 2, 3, …, pelo menos 15 registros)
#
# valor (a maioria entre 100 e 2000, mas inclua 1 ou 2 valores muito altos, como 50.000 ou 100.000)
#
# Exemplo de início:

# %%
import pandas as pd
dados = {
    "id_venda": list(range(1, 16)),
    "valor": [300, 450, 500, 600, 700,
              800, 1200, 1500, 1600, 1800,
              2000, 2200, 2500, 50000, 80000]
}
df_faturamento = pd.DataFrame(dados)
