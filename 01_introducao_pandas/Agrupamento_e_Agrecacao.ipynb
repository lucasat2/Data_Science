# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasat2/Jornada_python/blob/main/introducao_pandas/Agrupamento_e_Agrecacao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np


data = {
	'Escola': ['A', 'B', 'A', 'B', 'A' , 'B' , 'A', 'B'],
	'Student ID': [1001, 1002, 1003, 1004, 1005, 1006,1007, 1008],
	'Matematica': np.random.randint(60,100,8),
	'Ingles': np.random.randint(60,100,8),
	'Historia': np.random.randint(60,100,8)
	}

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#   Escola  Student ID  Matematica  Ingles  Historia
# 0      A        1001          77      88        67
# 1      B        1002          60      60        98
# 2      A        1003          64      72        81
# 3      B        1004          68      79        99
# 4      A        1005          64      93        69
# 5      B        1006          73      85        79
# 6      A        1007          89      63        97
# 7      B        1008          91      75        84

# %%
agrupa = df.groupby('Escola')

# %%
media_escola = agrupa.mean()
print(media_escola)
# Out:
#         Student ID  Matematica  Ingles  Historia
# Escola
# A           1004.0        73.5   79.00      78.5
# B           1005.0        73.0   74.75      90.0

# %%
#Aplicando multiplas operacoes

agg_data = agrupa.agg({
	'Matematica' : ['mean','median','std']}	)
print(agg_data)
# Out:
#        Matematica
#              mean median        std
# Escola
# A            73.5   70.5  12.013881
# B            73.0   70.5  13.140269

# %% [markdown]
# * O desvio padrão nos diz que neste caso que quanto menor for, mais as notas são parecidas na escola B. Já na escola A o desvio está mais alto, o que significa que alunos podem ter tirado notas variadas entre altas e baixas

# %%
# Agrupando por mais de uma coluna
# Adicionando nova coluna

df['Turma' ] = ['X', 'X', 'Y' , 'Y','X' , 'Y' , 'Y' , 'X']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Agrupando por multiplas colunas

grouped_multi = df.groupby(['Escola','Turma'])

# %%
grouped_multi.mean()
# Out:
#               Student ID  Matematica  Ingles  Historia
# Escola Turma
# A      X          1003.0        70.5    90.5      68.0
#        Y          1005.0        76.5    67.5      89.0
# B      X          1005.0        75.5    67.5      91.0
#        Y          1005.0        70.5    82.0      89.0

# %%
df
# Out:
#   Escola  Student ID  Matematica  Ingles  Historia Turma
# 0      A        1001          77      88        67     X
# 1      B        1002          60      60        98     X
# 2      A        1003          64      72        81     Y
# 3      B        1004          68      79        99     Y
# 4      A        1005          64      93        69     X
# 5      B        1006          73      85        79     Y
# 6      A        1007          89      63        97     Y
# 7      B        1008          91      75        84     X

# %% [markdown]
# DESAFIO
#
# Use agrupamento e agregação para calcular a pontuação média em
# todas as turmas por escola. Queremos a pontuação média para
# 'Matemática', 'Inglês' e 'História', dividida por 'Turma' (portanto, nossas
# classes 'X' e 'Y') e dividida por 'Escola'. Responda a esta pergunta usando
# os conceitos que acabamos de discutir e abordaremos a resposta na
# próxima aula.

# %%
pontuacao_agrupada = df.groupby(['Escola', 'Turma']).mean()
print(pontuacao_agrupada)
# Out:
#               Student ID  Matematica  Ingles  Historia
# Escola Turma
# A      X          1003.0        70.5    90.5      68.0
#        Y          1005.0        76.5    67.5      89.0
# B      X          1005.0        75.5    67.5      91.0
#        Y          1005.0        70.5    82.0      89.0
