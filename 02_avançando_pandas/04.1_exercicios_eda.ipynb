# %% [markdown]
# # Exercícios práticos da Aula 3

# %% [markdown]
# ## Exercício 1 – Loja de Roupas
# Use o DataFrame `df_loja` (ou crie um semelhante) com as colunas:
# * `produto`
# * `categoria`
# * `preco`
# * `quantidade_vendida`

# %%
import pandas as pd

dados = {
    "produto": [
        "Camiseta Básica", "Calça Jeans", "Vestido Floral", "Jaqueta Couro",
        "Camiseta Básica", "Calça Jeans", "Shorts Jeans", "Moletom", "Moletom", "Vestido Floral"
    ],
    "categoria": [
        "Camisetas", "Calças", "Vestidos", "Jaquetas",
        "Camisetas", "Calças", "Shorts", "Moletons", "Moletons", "Vestidos"
    ],
    "preco": [49.90, 159.90, 199.90, 399.90, 59.90, 149.90, 89.90, 129.90, 139.90, 219.90],
    "quantidade_vendida": [120, 80, 45, 10, 150, 70, 60, 90, 110, 30]
}

df_loja = pd.DataFrame(dados)
df_loja

# %% [markdown]
# ### Tarefa 1.1
# Use `df_loja.describe()` para ver as estatísticas das colunas numéricas (`preco` e `quantidade_vendida`).

# %% [markdown]
# ### Tarefa 1.2
# Em texto, responda:
# * Qual é o preço médio dos produtos?
# * Qual é o valor mínimo e máximo de `quantidade_vendida`?

# %% [markdown]
# ### Tarefa 1.3
# Use `df_loja["categoria"].value_counts()` para descobrir:
# * Quantas peças existem em cada categoria.
# * Qual categoria é mais frequente.

# %% [markdown]
# ### Tarefa 1.4
# Use `df_loja["preco"].quantile(0.25)`, `0.5` e `0.75` para calcular os quartis de preço.

# %% [markdown]
# ### Tarefa 1.5
# Em texto, explique:
# * Até quanto custam os 25% mais baratos?
# * Qual é a mediana?
# * Acima de quanto estão os 25% mais caros?

# %% [markdown]
# ### Tarefa 1.6 (Opcional)
# Use a técnica do IQR para verificar se existe algum produto com preço possivelmente “fora da curva”.

# %% [markdown]
# ## Exercício 2 – Plataforma de Cursos Online
# Crie (ou reutilize) um DataFrame `df_cursos` com as colunas:
# * `curso`
# * `area`
# * `avaliacao` (ex.: 0 a 5)
# * `horas` (carga horária)
# * `qtde_alunos`

# %%
dados_cursos = {
    "curso": [
        "Python Básico", "Python Avançado", "Data Science com Python",
        "Introdução ao SQL", "Machine Learning", "Excel para Dados",
        "Power BI Essencial", "Estatística Aplicada"
    ],
    "area": [
        "Programação", "Programação", "Data Science",
        "Banco de Dados", "Data Science", "Ferramentas",
        "Ferramentas", "Estatística"
    ],
    "avaliacao": [4.5, 4.7, 4.8, 4.2, 4.6, 4.3, 4.4, 4.1],
    "horas": [12, 20, 25, 10, 30, 8, 15, 18],
    "qtde_alunos": [1200, 800, 950, 600, 700, 1100, 900, 500]
}

df_cursos = pd.DataFrame(dados_cursos)
df_cursos

# %% [markdown]
# ### Tarefa 2.1
# Use `df_cursos["area"].value_counts()` para ver:
# * Quantos cursos existem em cada área.
# * Qual área tem mais cursos.

# %% [markdown]
# ### Tarefa 2.2
# Descubra:
# * Qual curso tem mais alunos (use `sort_values("qtde_alunos", ascending=False).head(1)`).
# * Qual curso tem melhor avaliação.

# %% [markdown]
# ### Tarefa 2.3
# Use `df_cursos[["avaliacao", "horas", "qtde_alunos"]].describe()` e responda em texto:
# * Qual é a avaliação média dos cursos?
# * Em média, quantas horas tem um curso?
# * O número de alunos varia muito? (olhe `min`, `max` e `std` de `qtde_alunos`).

# %% [markdown]
# ### Tarefa 2.4
# Escreva 2 insights em formato de frase, como se estivesse preparando um mini-relatório para o time de produto.
#
# Exemplos:
# * “Cursos de Data Science têm avaliações médias maiores que as demais áreas.”
# * “Apesar de poucos cursos na área X, eles concentram muitos alunos.”

# %% [markdown]
# > *Insight 1:*
#
# > *Insight 2:*
