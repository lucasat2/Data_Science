# %% [markdown]
# # Exercícios: Criando e Modificando Colunas

# %% [markdown]
# ## Exercício 1 – Margem de lucro
# Crie um DataFrame `df_produtos` com as colunas:
# * `produto`
# * `categoria`
# * `custo`
# * `preco_venda`
#
# Use pelo menos 6–8 produtos, misturando categorias (ex.: Eletrônicos, Roupas, Acessórios).

# %%
import pandas as pd

dados_produtos = {
    "produto": ["Smartphone", "Camiseta", "Relógio", "Fone Bluetooth", "Calça Jeans", "Monitor", "Mochila", "Teclado"],
    "categoria": ["Eletrônicos", "Roupas", "Acessórios", "Eletrônicos", "Roupas", "Eletrônicos", "Acessórios", "Eletrônicos"],
    "custo": [1200.0, 35.0, 150.0, 80.0, 60.0, 600.0, 45.0, 100.0],
    "preco_venda": [2000.0, 89.90, 350.0, 199.90, 149.90, 950.0, 120.0, 250.0]
}

df_produtos = pd.DataFrame(dados_produtos)
df_produtos
# Out:
#           produto    categoria   custo  preco_venda
# 0      Smartphone  Eletrônicos  1200.0       2000.0
# 1        Camiseta       Roupas    35.0         89.9
# 2         Relógio   Acessórios   150.0        350.0
# 3  Fone Bluetooth  Eletrônicos    80.0        199.9
# 4     Calça Jeans       Roupas    60.0        149.9
# 5         Monitor  Eletrônicos   600.0        950.0
# 6         Mochila   Acessórios    45.0        120.0
# 7         Teclado  Eletrônicos   100.0        250.0

# %% [markdown]
# ### Tarefa 1.1 e 1.2
# * Crie uma coluna `lucro = preco_venda - custo`.
# * Crie uma coluna `margem_pct = lucro / preco_venda * 100`.

# %%
df['lucro'] = preco_venda - custo

# %% [markdown]
# ### Tarefa 1.3
# Arredonde `margem_pct` para 2 casas decimais.

# %% [markdown]
# ### Tarefa 1.4
# Crie um DataFrame `df_relatorio` ordenando do maior para o menor `margem_pct`.

# %% [markdown]
# ### Tarefa 1.5
# Reorganize as colunas na seguinte ordem:
# `produto, categoria, custo, preco_venda, lucro, margem_pct`

# %% [markdown]
# ### Tarefa 1.6
# Em texto, responda:
# * Qual produto tem a maior margem percentual?
# * Existe algum produto com margem muito baixa que poderia ser revisado no preço?

# %% [markdown]
# > *Sua resposta aqui*

# %% [markdown]
# ## Exercício 2 – Ranking de alunos
# Crie um DataFrame `df_alunos` com as colunas:
# * `aluno`
# * `nota_prova1`
# * `nota_prova2`
#
# Use pelo menos 5–8 alunos com notas diversas.

# %%
dados_alunos = {
    "aluno": ["Ana", "Bruno", "Carla", "Daniel", "Eduarda", "Felipe", "Gabriela"],
    "nota_prova1": [8.5, 6.0, 9.5, 5.5, 7.0, 4.5, 8.0],
    "nota_prova2": [7.5, 8.0, 9.0, 6.5, 9.5, 5.0, 8.5]
}

df_alunos = pd.DataFrame(dados_alunos)
df_alunos

# %% [markdown]
# ### Tarefa 2.1 e 2.2
# * Crie uma coluna `media` com a média das duas provas.
# * Crie uma coluna `status` com:
#     * "Aprovado" se `media >= 7`
#     * "Reprovado" caso contrário.

# %% [markdown]
# ### Tarefa 2.3
# Arredonde as médias para 2 casas decimais.

# %% [markdown]
# ### Tarefa 2.4
# Ordene o DataFrame do aluno com maior média para o menor.

# %% [markdown]
# ### Tarefa 2.5
# Reorganize as colunas na ordem:
# `aluno, nota_prova1, nota_prova2, media, status`

# %% [markdown]
# ### Tarefa 2.6
# Em texto, responda:
# * Quantos alunos foram aprovados?
# * Quem ficou em primeiro lugar no ranking?

# %% [markdown]
# > *Sua resposta aqui*
