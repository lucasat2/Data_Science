# %% [markdown]
# # Exercício 1 – E-commerce CSV
#
# Imagine que você trabalha numa plataforma de e-commerce e recebeu um arquivo vendas_ecommerce.csv com as colunas:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Tarefas:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df_vendas = pd.read_csv("vendas_ecommerce.csv", sep=";", encoding="latin-1")

# %% [markdown]
# Crie um segundo DataFrame df_resumo lendo apenas as colunas:
# ![image.png](attachment:image.png)

# %%
df_resumo = pd.read_csv("vendas_ecommerce.csv",sep=";",encoding="latin-1",usecols=["order_id", "valor", "cidade"]
)

# %% [markdown]
# Mostre as primeiras 5 linhas de df_resumo com head() e os tipos com dtypes.

# %%
df_resumo.head()
df_resumo.dtypes()

# %%
 # Salvando o arquivo
df_resumo.to_csv("vendas_filtrado.csv", index=False, encoding="utf-8")

# %% [markdown]
# Exercício 2 – Planilha de RH
#
# ![image.png](attachment:image.png)

# %%
# Ler apenas a aba de colaboradores 
df_colab = pd.read_excel("rh_empresa.xlsx", sheet_name="colaboradores")

df_colab.head()
df_colab.dtypes()

# %% [markdown]
# Leia a aba setores em um DataFrame df_setores

# %%
df_setores = pd.read_excel("rh_empresa.xlsx", sheet_name="setores")
df_setores.head()
