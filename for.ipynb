# %%
pessoas = {
    'Alice':25, 'Rogerio':44,'Lucas':68,'Afranio':44
}
for nome,idade in pessoas.items():
    print('Nome:',nome,'/','Idade:',idade)
# Out:
# Nome: Alice / Idade: 25
# Nome: Rogerio / Idade: 44
# Nome: Lucas / Idade: 68
# Nome: Afranio / Idade: 44
